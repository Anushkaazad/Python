# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkaazad/Python/blob/main/18101084_B_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc7cdc4e-df54-4f22-b70c-81aa2a9ef31a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc7cdc4e-df54-4f22-b70c-81aa2a9ef31a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 18101084_B_Assignment_1.png to 18101084_B_Assignment_1.png

# %%
Image('18101084_B_Assignment_1.png', width = 1200)

# %%
class Teacher:
  def __init__(self,teaching_method):
    self.teaching_method=teaching_method
    print("teachers like our parents!")
     
  def skill(self,teach):
       print('skilled...',teach)

# %%
class Admistrative(Teacher):
  def monitor(self,rules):
    print("monitoring......",rules)
  def gender(self):
    print("female")

# %%
cse_admistrative=Admistrative("strict")
# Out:
# teachers like our parents!

# %%
cse_admistrative.monitor("carefully")
# Out:
# monitoring...... carefully

# %%
cse_admistrative.skill("develop")
# Out:
# skilled... develop

# %%
class Instructor(Teacher):
  def guide(self,somthing):
    print("guiding.....",somthing)
  def gender(self):
    print("male")

# %%
cse_instructor=Instructor("strict")
# Out:
# teachers like our parents!

# %%
cse_instructor.guide("somthing")
# Out:
# guiding..... somthing

# %%
class DeptHead(Admistrative,Instructor):
  def __init__(self):
    print("head")

  def evaluate(self):
    print("evaluate each student")

# %%
cse_head=DeptHead()
# Out:
# head

# %%
cse_head.monitor("carefully")
# Out:
# monitoring...... carefully

# %%
cse_head.gender()
# Out:
# female
